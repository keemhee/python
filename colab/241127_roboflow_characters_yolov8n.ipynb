# %%
# !nvidia-smi
# Out:
# Wed Nov 27 02:40:44 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="znzmK1TZOtY1aYoVFfty")
project = rf.workspace("kim-ewj00").project("characters-xxgj0")
version = project.version(1)
dataset = version.download("yolov8")


# data.yaml 파일에서 테스트 이미지, 트레인 이미지, 밸리드이미지 경로 복사해서 넣어주기
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to characters-1 in yolov8:: 100%|██████████| 300/300 [00:00<00:00, 8669.86it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.3/896.3 kB 27.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect train model=yolov8n.pt data=/content/characters-1/data.yaml epochs = 20 imgsz=416
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train2/weights/best.pt source=/content/p.jpg
#data엔 data.yaml경로. source엔 리스트디렉토리. 둘 중 하나만 지정
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/p.jpg: 416x320 1 pooh, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 593.7ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
