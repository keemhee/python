# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 kB 11.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# yolo version 8

# %%
# You Only Look Once
# yolov8n.pt  욜로버전8나노. 모델(n나노, s스몰, l라지, x엑스라지)
# yolo task mode argument
# 모드(train/ predict/ evaluate/ export) 필수. 디폴트 train.
# 태스크(detect/ segment/ classify/ pose/ obb)랑 아규먼트(confidence)는 옵션.
# 얘네가 어떻게 결과를 내는지

# !yolo predict model=yolov8n.pt source =/content/image.webp show = True
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 74.9MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/image.webp: 320x640 (no detections), 254.6ms
# Speed: 16.9ms preprocess, 254.6ms inference, 18.1ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source =/content/zoo.webp show = True

# 분류 + 바운딩박스
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/zoo.webp: 640x480 2 persons, 1 elephant, 2 zebras, 1 giraffe, 1 umbrella, 1 potted plant, 1 clock, 216.1ms
# Speed: 6.5ms preprocess, 216.1ms inference, 21.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source =/content/mercury.jpg show = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/mercury.jpg: 608x640 1 person, 1 vase, 299.8ms
# Speed: 13.6ms preprocess, 299.8ms inference, 2.6ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source =/content/earth.jpg show = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/earth.jpg: 544x640 (no detections), 371.7ms
# Speed: 11.9ms preprocess, 371.7ms inference, 3.4ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source =/content/images.jpg show = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images.jpg: 384x640 4 persons, 173.9ms
# Speed: 3.9ms preprocess, 173.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Microsoft COCO Dataset

# %%
#segmentation
# !yolo predict model=yolov8n-seg.pt source =/content/zoo.webp show = True
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 70.4MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/zoo.webp: 640x480 3 persons, 2 zebras, 2 giraffes, 386.3ms
# Speed: 8.6ms preprocess, 386.3ms inference, 32.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo segment model=yolov8n-seg.pt source =/content/zoo.webp show = True

# runs - segment - train 폴더가 생김
# weights에는 best.pt, last.pt가 있음 pt는 모델.
# 웨이트에서 라스트는 제일 마지막 epoch, 베스트는 그 중에서 가장 좋은 거라 보통 이거 가져다가 inference삼음
# Out:
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'benchmark', 'predict', 'export', 'val', 'train', 'track'}. Using default 'mode=train'.
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8-seg.yaml'.
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo detect predict model=yolov8n.pt source =/content/image.webp show = True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/image.webp: 320x640 (no detections), 167.9ms
# Speed: 7.5ms preprocess, 167.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 하나씩 분해해서 어떻게 작동하는지 보기

# %%
import cv2
from google.colab.patches import cv2_imshow
model = YOLO('yolov8n.pt')
img = cv2.imread('/content/zoo.webp')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=675x900>

# %%
results = model('/content/zoo.webp')
print(results[0].boxes)
#0번째 이미지의 박스 안에 결과값 이미지가 들어있?
# Out:
# image 1/1 /content/zoo.webp: 640x480 2 persons, 1 elephant, 2 zebras, 1 giraffe, 1 umbrella, 1 potted plant, 1 clock, 186.8ms
# Speed: 5.5ms preprocess, 186.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([22., 22., 23.,  0., 74., 25.,  0., 58., 20.])
# conf: tensor([0.8489, 0.8339, 0.7732, 0.3853, 0.3819, 0.2684, 0.2643, 0.2585, 0.2530])
# data: tensor([[4.9296e+02, 5.2103e+02, 6.7441e+02, 8.6348e+02, 8.4890e-01, 2.2000e+01],
#         [2.4347e+02, 5.2532e+02, 4.0517e+02, 8.8801e+02, 8.3387e-01, 2.2000e+01],
#         [2.4452e-01, 9.0668e+01, 1.7926e+02, 3.5620e+02, 7.7324e-01, 2.3000e+01],
#         [1.9590e+02, 9.3742e+01, 2.8770e+02, 2.2036e+02, 3.8526e-01, 0.0000e+00],
#         [2.8723e+02, 1.0845e+02, 3.8715e+02, 2.0600e+02, 3.8185e-01, 7.4000e+01],
#         [5.8946e+02, 8.2496e+02, 6.7467e+02, 8.9962e+02, 2.6844e-01, 2.5000e+01],
# ...

# %%
print(results[0].boxes.xyxy)
x1,y1,x2,y2 = results[0].boxes.xyxy[0]
# Out:
# tensor([[4.9296e+02, 5.2103e+02, 6.7441e+02, 8.6348e+02],
#         [2.4347e+02, 5.2532e+02, 4.0517e+02, 8.8801e+02],
#         [2.4452e-01, 9.0668e+01, 1.7926e+02, 3.5620e+02],
#         [1.9590e+02, 9.3742e+01, 2.8770e+02, 2.2036e+02],
#         [2.8723e+02, 1.0845e+02, 3.8715e+02, 2.0600e+02],
#         [5.8946e+02, 8.2496e+02, 6.7467e+02, 8.9962e+02],
#         [3.8165e+02, 9.8174e+01, 4.6256e+02, 2.2000e+02],
#         [3.7065e-01, 3.8213e+02, 1.6920e+02, 8.4969e+02],
#         [4.1703e+01, 5.7295e+02, 2.4894e+02, 8.5203e+02]])

# %%
#그냥 나오는 거 하나씩 네모네모 그려보기

#results[0]에서 confidence랑 class찾기

print(results[0].boxes.xyxy)
x1,y1,x2,y2 = results[0].boxes.xyxy[0]
print(results[0].boxes.conf)
print(results[0].boxes.cls)

for result in results:
  boxes = result.boxes.xyxy
  classes = result.boxes.cls
  confidences = result.boxes.conf
  names = result.names
  #for i in range(len(result.boxes.xyxy)):
    #x1, y1, x2, y2 = result.boxes.xyxy[i]
    #print(x1)
    # 정수로
    #x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
    # 박스 그리기
    #cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255), 3)
  for box, cls, conf in zip(boxes, classes, confidences):
    #확인     =>  타입확인. 텐서   => 정수로
    #print(box)    print(type(box))   print(int(box))
    #print(conf)
    #print(names[int(cls)])
    name = names[int(cls)]
    if names[int(cls)] == 'giraffe':
      #x1,y1,x2,y2 맵으로 처리
      x1, y1, x2, y2 = map(int, box)
      cv2.putText(img, f'{name} {conf:.2f}', (x1,y1-5), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0), 3)
      cv2.rectangle(img, (x1, y1), (x2, y2), (0, 0, 255), 3)

cv2_imshow(img)
# Out:
# tensor([[4.9296e+02, 5.2103e+02, 6.7441e+02, 8.6348e+02],
#         [2.4347e+02, 5.2532e+02, 4.0517e+02, 8.8801e+02],
#         [2.4452e-01, 9.0668e+01, 1.7926e+02, 3.5620e+02],
#         [1.9590e+02, 9.3742e+01, 2.8770e+02, 2.2036e+02],
#         [2.8723e+02, 1.0845e+02, 3.8715e+02, 2.0600e+02],
#         [5.8946e+02, 8.2496e+02, 6.7467e+02, 8.9962e+02],
#         [3.8165e+02, 9.8174e+01, 4.6256e+02, 2.2000e+02],
#         [3.7065e-01, 3.8213e+02, 1.6920e+02, 8.4969e+02],
#         [4.1703e+01, 5.7295e+02, 2.4894e+02, 8.5203e+02]])
# tensor([0.8489, 0.8339, 0.7732, 0.3853, 0.3819, 0.2684, 0.2643, 0.2585, 0.2530])
# tensor([22., 22., 23.,  0., 74., 25.,  0., 58., 20.])
# <PIL.Image.Image image mode=RGB size=675x900>

# %%
#results[0]에서 confidence랑 class찾기

print(results[0].boxes.xyxy)
x1,y1,x2,y2 = results[0].boxes.xyxy[0]

print(results[0].boxes.conf)

print(results[0].boxes.cls)
# Out:
# tensor([[4.9296e+02, 5.2103e+02, 6.7441e+02, 8.6348e+02],
#         [2.4347e+02, 5.2532e+02, 4.0517e+02, 8.8801e+02],
#         [2.4452e-01, 9.0668e+01, 1.7926e+02, 3.5620e+02],
#         [1.9590e+02, 9.3742e+01, 2.8770e+02, 2.2036e+02],
#         [2.8723e+02, 1.0845e+02, 3.8715e+02, 2.0600e+02],
#         [5.8946e+02, 8.2496e+02, 6.7467e+02, 8.9962e+02],
#         [3.8165e+02, 9.8174e+01, 4.6256e+02, 2.2000e+02],
#         [3.7065e-01, 3.8213e+02, 1.6920e+02, 8.4969e+02],
#         [4.1703e+01, 5.7295e+02, 2.4894e+02, 8.5203e+02]])
# tensor([0.8489, 0.8339, 0.7732, 0.3853, 0.3819, 0.2684, 0.2643, 0.2585, 0.2530])
# tensor([22., 22., 23.,  0., 74., 25.,  0., 58., 20.])

# %% [markdown]
# # //여기까진 detection mode predict
#
# 이제 train

# %%
# yolo detection mode=train args
# cls, xyxy 라벨링

# %%
# train: ./dataset/images/train 들어가면 내가 넣은 이미지들이 있으면 그걸 한번 지정해줘야함
# val: ./dataset/images/val validation dataset
# test: ./dataset/images/test

# nc(number of classes): 아무것도 없을 때 배경만들어줘도 좋음. 양불량배경 -> 3개 클래스
# names: ['good', 'bad', 'background']
# 자동으로 해주지만 일단은 만들어보자.

# %%
# yolo roboflow
