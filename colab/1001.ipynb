# %%
import cv2
from google.colab.patches import cv2_imshow


file = '/content/cat2.jpg'
img = cv2.imread(file)
cv2_imshow(img)
print(img)

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
print(img_gray)

# %%
import random

left_gloves = []
right_gloves = []

for i in range(random.randint(1, 100)):
  j = random.randint(1, 10)
  left_gloves.append(j)

print(left_gloves)

for i in range(random.randint(1, 100)):
  j = random.randint(1, 10)
  right_gloves.append(j)

print(right_gloves)
# Out:
# [9, 1, 7, 5, 10, 9, 6, 1, 6, 8, 1, 6, 4, 6, 10, 4, 4, 3, 9, 6, 4, 6, 7]
# [7, 3, 8, 4, 10, 10, 10, 5]

# %%
left_gloves.sort()
right_gloves.sort()

left_count={}
right_count={}

for num in left_gloves:
  if num in left_count:
    left_count[num] += 1
  else:
    left_count[num] = 1

print(left_count)

for num in right_gloves:
  if num in right_count
