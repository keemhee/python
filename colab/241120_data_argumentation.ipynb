# %% [markdown]
# ```
# 인터넷에서 이미지 다운받아서 해보기.
# internet image download
# 데이터 구축
# 데이터를 무한으로 받을 수 없기 때문에 증강해 변형해 활용
# ```

# %%
# !pip install simple_image_download
# Out:
# ...
# INFO: pip is looking at multiple versions of simple-image-download to determine which version is compatible with other requirements. This could take a while.
# ...

# %%
from simple_image_download import simple_image_download as sid
import os

# %%
class_names = ['cat', 'dog', 'hamster']

# %%
#y_data 힌트
for i, name in enumerate(class_names):
  print(f'{i} : {name}')      #인덱스까찌 같이 뽑겠다.
# Out:
# 0 : cat
# 1 : dog
# 2 : hamster

# %%
response = sid.simple_image_download
for class_name in class_names:
  response().download(class_name, 5)

# %%
import cv2
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.layers import RandomRotation, RandomZoom, RandomBrightness, RandomFlip
from tensorflow.keras.models import Sequential
import numpy as np

# %%
'''data_argumentation = Sequential([
    RandomRotation(0.5, input_shape = (160, 120, 3)),
    RandomFlip('horizontal'),#'vertical
    RandomBrightness(0.5),
    RandomZoom(1)
])'''
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
base_dir = '/content/simple_images'
X_data = []               #이제 데이터를 한꺼번에 묶어줘야하고, 라벨도 하나씩 달아야함-2
y_data = []
'''
for class_name in class_names:
  folder_dir = os.path.join(base_dir, class_name)
  #print(folder_dir)
  for file_name in os.listdir(folder_dir):
    #print(file_name)
    #cv2.imread('/content/simple_images/hamster/hamster_2.jpg') 이렇게 만들기?
    img_file = os.path.join(folder_dir, file_name)
    print(img_file)
    img = cv2.imread(img_file)  #img = cv2.imread('/content/simple_images/hamster/hamster_2.jpg') 밑에 한 거처럼 들어오게 함.
    #cv2_imshow(img)
    img_resized = cv2.resize(img, (150, 150))
    img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
    #img_batch = np.expand_dims(img_rgb, axis = 0)
    #print(img_batch.shape)  #이제 데이터를 한꺼번에 묶어줘야하고, 라벨도 하나씩 달아야함-1
    X_data.append(img_rgb)
X_data = np.array(X_data)
print(X_data.shape)'''

for i, class_name in enumerate(class_names):
    folder_dir = os.path.join(base_dir, class_name)

    for file_name in os.listdir(folder_dir):
      img_file = os.path.join(folder_dir, file_name)
      img = cv2.imread(img_file)
      img_resized = cv2.resize(img, (150, 150))
      img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
      X_data.append(img_rgb)
      y_data.append(i)

X_data = np.array(X_data)
y_data = np.array(y_data)
print(X_data.shape)
print(y_data)
print(y_data.shape)
# Out:
# (9, 150, 150, 3)
# [0 0 0 1 1 1 2 2 2]
# (9,)

# %% [markdown]
# ```
# 모델
# 1. data argumentation X -> train, test split -> cnn(conv) -> model fit -> accuracy
# 2. data argumentation O
# ```

# %%
'''img = cv2.imread('/content/simple_images/hamster/hamster_2.jpg')

#cv2_imshow(img)
print(img.shape) #너무 큼
img_resized = cv2.resize(img, (160, 120))
img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
img_batch = np.expand_dims(img_rgb, axis = 0)

cv2_imshow(img_resized)
cv2_imshow(img_rgb)
print(img_batch.shape)'''
# Out:
# "img = cv2.imread('/content/simple_images/hamster/hamster_2.jpg')\n\n#cv2_imshow(img)\nprint(img.shape) #너무 큼\nimg_resized = cv2.resize(img, (160, 120))\nimg_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)\nimg_batch = np.expand_dims(img_rgb, axis = 0)\n\ncv2_imshow(img_resized)\ncv2_imshow(img_rgb)\nprint(img_batch.shape)"

# %%
'''img_argumented = data_argumentation(img_batch)'''
# Out:
# 'img_argumented = data_argumentation(img_batch)'

# %%
'''#얘가 갖고 있는 형식이랑 이미지 형식이랑 다름
#cv2_imshow(img_argumented) 그래서 안 나옴
img_arg = tf.squeeze(img_argumented).numpy()

#원본?이랑 비교
img_bgr = cv2.cvtColor(img_arg, cv2.COLOR_RGB2BGR)
cv2_imshow(img_resized)
cv2_imshow(img_bgr)'''
# Out:
# '#얘가 갖고 있는 형식이랑 이미지 형식이랑 다름\n#cv2_imshow(img_argumented) 그래서 안 나옴\nimg_arg = tf.squeeze(img_argumented).numpy()\n\n#원본?이랑 비교\nimg_bgr = cv2.cvtColor(img_arg, cv2.COLOR_RGB2BGR)\ncv2_imshow(img_resized)\ncv2_imshow(img_bgr)'
