# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.3/896.3 kB 19.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo detect predict model=yolo11n-obb.pt source=/content/field.jpg show=True
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=obb' model. Ignoring 'task=detect' and updating to 'task=obb' to match model.
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n-obb summary (fused): 257 layers, 2,656,648 parameters, 0 gradients, 6.6 GFLOPs
#
# image 1/1 /content/field.jpg: 576x1024 344.1ms
# Speed: 26.5ms preprocess, 344.1ms inference, 29.4ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to runs/obb/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/field.jpg')
model=YOLO('yolo11n-obb.pt')

# %%
#이미지 한장이니까
result=model(img)[0]
# Out:
# 0: 576x1024 294.3ms
# Speed: 6.7ms preprocess, 294.3ms inference, 3.3ms postprocess per image at shape (1, 3, 576, 1024)

# %%
print(result)
#사람에겐 맞지 않음. 블록을 요리조리 잘 잡음. names에 뭐뭐 인식하는지 나옴

#print(result.obb) #xywhr 여기서 r이 얼마나 돌았는지

#xywhr 보기
print(result.obb.xywhr)
#print(result.obb.xywhr.shape)

#얼마나 돌았는지 r뽑기
print(result.obb.xywhr[0][4])
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'plane', 1: 'ship', 2: 'storage tank', 3: 'baseball diamond', 4: 'tennis court', 5: 'basketball court', 6: 'ground track field', 7: 'harbor', 8: 'bridge', 9: 'large vehicle', 10: 'small vehicle', 11: 'helicopter', 12: 'roundabout', 13: 'soccer ball field', 14: 'swimming pool'}
# obb: ultralytics.engine.results.OBB object
# orig_img: array([[[ 0,  0,  3],
#         [ 1,  4,  8],
#         [ 0,  4,  5],
#         ...,
#         [24, 23, 33],
#         [ 0,  0,  6],
#         [ 7,  4, 13]],
#
#        [[ 0,  0,  3],
#         [ 0,  3,  7],
#         [ 6, 10, 11],
#         ...,
#         [43, 42, 52],
#         [ 4,  1, 10],
#         [ 0,  0,  6]],
#
#        [[ 0,  0,  3],
#         [ 0,  0,  3],
#         [ 6, 10, 11],
#         ...,
#         [43, 42, 52],
#         [ 4,  1, 10],
#         [ 2,  0,  8]],
#
#        ...,
#
#        [[ 2,  7,  8],
# ...
