# %% [markdown]
# 8.

# %%
def is_prime(num):

  if num < 1:
    return False
  else:
    for i in range(2, num):
      if num % i == 0:
        return print(f'{num}: 소수가 아닙니다')
    return print(f'{num}: 소수입니다')

num = int(input("숫자를 넣어주세요 "))
result = is_prime(num)
# Out:
# 숫자를 넣어주세요 7
# 7: 소수입니다
